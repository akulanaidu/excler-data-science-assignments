# %%
import pandas as pd

# loading data set 
df = pd.read_csv('sales_data_with_discounts.csv')
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
# Identify numerical columns in the dataset.

numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
print(numerical_columns)
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Calculate the mean, median, mode, and standard deviation for the numerical columns
df_numerical = df[numerical_columns]

# Mean
mean = df_numerical.mean()

# Median
median = df_numerical.median()

# Mode
mode = df_numerical.mode().iloc[0]

# Standard deviation
std = df_numerical.std()

# Print the results
print("Mean:")
print(mean)
print("\nMedian:")
print(median)
print("\nMode:")
print(mode)
print("\nStandard Deviation:")
print(std)
# Out:
# Mean:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64
#
# Median:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64
#
# Mode:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64
#
# Standard Deviation:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
# By interpreting these statistics, we can gain insights into the mean,median ,mode,Standard deviatian of the numerical data in the sales dataset. This information can be helpful for understanding patterns and trends in the data, as well as for making predictions and informed decisions.

# %%
#Plotting histograms for each numerical column.

import matplotlib.pyplot as plt

# Plot histograms for each numerical column
for column in numerical_columns:
    plt.hist(df[column])
    plt.title(f"Histogram of {column}")
    plt.show()

# %%
#skewness :- Volume is positive, Avg Price is  positive, Total Sales Value is positive, Discount Rate (%) is negative, Discount Amount is positive, Net Sales Value is positive.

# %%
# Create boxplots for numerical variables

for column in numerical_columns:
    plt.boxplot(df[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print ('categorical cloumns',[categorical_columns])
# Out:
# categorical cloumns [Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')]

# %%
# BarChart Analysis for Categorical Column and count of each category for above data

# Count the number of occurrences for each category in the categorical columns
for column in categorical_columns:
  unique_categories = df[column].unique()
  category_counts = df[column].value_counts()

  # Create a bar chart for each categorical column
  plt.bar(unique_categories, category_counts)
  plt.title(f"Bar Chart for {column}")
  plt.xlabel(column)
  plt.ylabel("Count")
  plt.show()

  # Print the count of each category
  print(f"Count of categories in {column}:")
  print(category_counts)
# Out:
# Count of categories in Date:
# Date
# 01-04-2021    30
# 02-04-2021    30
# 03-04-2021    30
# 04-04-2021    30
# 05-04-2021    30
# 06-04-2021    30
# 07-04-2021    30
# 08-04-2021    30
# 09-04-2021    30
# 10-04-2021    30
# 11-04-2021    30
# 12-04-2021    30
# 13-04-2021    30
# 14-04-2021    30
# 15-04-2021    30
# Name: count, dtype: int64
# Count of categories in Day:
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64
# Count of categories in SKU:
# SKU
# M01    15
# M02    15
# L09    15
# L08    15
# L07    15
# L06    15
# L05    15
# L04    15
# L03    15
# L02    15
# L01    15
# F10    15
# F09    15
# F08    15
# F07    15
# F06    15
# F05    15
# F04    15
# F03    15
# F02    15
# F01    15
# M10    15
# M09    15
# M08    15
# M07    15
# M06    15
# M05    15
# M04    15
# M03    15
# L10    15
# Name: count, dtype: int64
# Count of categories in City:
# ...

# %%
#Standardization (z-score normalization) is a technique used to transform numerical variables to have a mean of 0 and a standard deviation of 1. This makes the variables more comparable and helps to improve the performance of many analytical models."

# %%
# Standardize the data
for column in numerical_columns:
  mean = df[column].mean()
  std = df[column].std()
  zscore_df=(df[column] - mean) / std


# Print the standardized data
df[numerical_columns].head()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.347417   0.091072           2.922469          -0.829365         3.948422
# 1  1.165831  -0.019548           1.329516          -0.851714         1.846958
# 2  0.456880   0.312312           1.561038          -1.350129         1.621190
# 3  0.220563   0.533552           1.717365          -1.947555         1.112568
# 4 -0.488389  -0.130168          -0.188242           0.672990         0.227598
#
#    Net Sales Value
# 0         2.801638
# 1         1.269613
# 2         1.543957
# 3         1.763847
# 4        -0.227342

# %%
# Show before and after comparisons of the data distributions.
for col in numerical_columns:
    print(f"Before standardization:")
    print(df[col].describe())
    print(f"After standardization:")
    print(df[numerical_columns].describe())
# Out:
# Before standardization:
# count    4.500000e+02
# mean     4.934325e-17
# std      1.000000e+00
# min     -9.610229e-01
# 25%     -4.883887e-01
# 50%     -2.520716e-01
# 75%      2.205626e-01
# max      6.128490e+00
# Name: Volume, dtype: float64
# After standardization:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  4.500000e+02  4.500000e+02       4.500000e+02       4.500000e+02
# mean   4.934325e-17  3.947460e-17       1.184238e-17      -3.552714e-17
# std    1.000000e+00  1.000000e+00       1.000000e+00       1.000000e+00
# min   -9.610229e-01 -5.621398e-01      -6.611811e-01      -2.404259e+00
# 25%   -4.883887e-01 -5.524605e-01      -6.156681e-01      -2.819928e-01
# 50%   -2.520716e-01 -4.979801e-01      -5.563034e-01       3.370428e-01
# 75%    2.205626e-01 -1.954841e-02       3.836378e-01       7.011977e-01
# max    6.128490e+00  2.745953e+00       3.217313e+00       1.146084e+00
#
#        Discount Amount  Net Sales Value
# ...

# %%
# Explain the need for converting categorical data into dummy variables
# Apply one-hot encoding to the categorical columns
df_encoded = pd.get_dummies(df, columns=categorical_columns)

# Display a portion of the transformed data
print(df_encoded.head())
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.347417   0.091072           2.922469          -0.829365         3.948422
# 1  1.165831  -0.019548           1.329516          -0.851714         1.846958
# 2  0.456880   0.312312           1.561038          -1.350129         1.621190
# 3  0.220563   0.533552           1.717365          -1.947555         1.112568
# 4 -0.488389  -0.130168          -0.188242           0.672990         0.227598
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0         2.801638             True            False            False
# 1         1.269613             True            False            False
# 2         1.543957             True            False            False
# 3         1.763847             True            False            False
# 4        -0.227342             True            False            False
#
# ...

# %%
#Conclusion
#The importance of data preprocessing steps like standardization and one-hot encoding in data analysis and machine learning
